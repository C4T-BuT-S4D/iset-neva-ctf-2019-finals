# %% [markdown]
# ##### Parameters were generated by https://github.com/J08nY/ecgen for anomalous curve

# %%
p = 0xaa770866774ff26543d1e3aedf24e6764d8bbe55f469f6feb3c132ed5bb945d4c2bd91f929440609

# %%
a = 0x03159621b42f4b91805265fd75bd8f5614fd4d5acf12fd4eccc764974f35ef0bb76fc1fd629ec21d
b = 0x6dba0c0bbf9d87526cc10e3d643cc84ff318bcbd472fd7b4b22a292336651d1326d8cd248045f338

# %%
E = EllipticCurve(GF(p), [a, b])

# %%
E.order() == p
# Out:
# True

# %%
flag = int(open('flag.txt', 'r').read().encode('hex'), 16)

# %%
xP = 0x3128e60923b6982a8cf8ef322fa883afc8313528aa75b0d87553ed1adaa6dbcb46292b01990fee47
yP = 0x1d8e221203f293734480fdd312dade5757c43589b48307ccff692c24da0719b397052501016d9579
P = E.point([xP, yP])

# %%
Q = flag * P

# %%
print('Points:')
print(P.xy())
print(Q.xy())
# Out:
# Points:
# (410174258556538740501478841895039006563949269433708762804055561658720526027809026382125807431239, 246599764812084320517242785159908503245759362520506121433581729948208875209261944567194201199993)
# (322101747091878922934379909559157366561706018987052678852476819683667123501085474489013810116026, 1350637714090645913866566938091748646434437628181692633371857416143030904296478092642847213303382)
